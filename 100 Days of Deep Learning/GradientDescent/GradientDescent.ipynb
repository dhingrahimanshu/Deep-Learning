# %% [markdown]
# <a href="https://colab.research.google.com/github/dhingrahimanshu/Deep-Learning/blob/main/100%20Days%20of%20Deep%20Learning/GradientDescent/GradientDescent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df  = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df['Purchased'].value_counts()
# Out:
# 0    257
# 1    143
# Name: Purchased, dtype: int64

# %%
df.drop(columns = ['User ID' , 'Gender'] , inplace = True)

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X = df.iloc[: , 0:2]
Y= df.iloc[: , -1]

# %%
X
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

x_train , x_test ,y_train , y_test = train_test_split(X ,Y , test_size = 0.2 , random_state = 10)

# %%
import keras
from keras.layers import Dense
from keras import Sequential

# %%
model = Sequential()
model.add(Dense(10 ,activation = 'sigmoid' ,input_dim =2))
model.add(Dense(128 ,activation = 'sigmoid'))
model.add(Dense(1 , activation = 'sigmoid'))

# %%
model2 = Sequential()
model2.add(Dense(10 ,activation = 'sigmoid' ,input_dim =2))
model2.add(Dense(128 ,activation = 'sigmoid'))
model2.add(Dense(1 , activation = 'sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy' , metrics = ['Accuracy'])
model2.compile(loss = 'binary_crossentropy' , metrics = ['Accuracy'])

# %%
x_train.shape
# Out:
# (320, 2)

# %%
import time

# %%
# Batch Gradient Descent

te = time.time()
history = model.fit(x_train , y_train , epochs = 10 ,batch_size =320)
ts = time.time()
print(ts - te)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5135 - Accuracy: 0.7906
# Epoch 2/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5119 - Accuracy: 0.7875
# Epoch 3/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5103 - Accuracy: 0.8000
# Epoch 4/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5087 - Accuracy: 0.7875
# Epoch 5/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5072 - Accuracy: 0.8000
# Epoch 6/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5056 - Accuracy: 0.7875
# Epoch 7/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5040 - Accuracy: 0.8000
# Epoch 8/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5024 - Accuracy: 0.8000
# Epoch 9/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5009 - Accuracy: 0.8031
# Epoch 10/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4993 - Accuracy: 0.8000
# 0.38159704208374023

# %%
#Stochastic Gradient Descent

te = time.time()
history = model2.fit(x_train , y_train , epochs = 10 ,batch_size =1)
ts = time.time()
print(ts - te)
# Out:
# Epoch 1/10
# 320/320 [==============================] - 1s 4ms/step - loss: 0.3677 - Accuracy: 0.8250
# Epoch 2/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3627 - Accuracy: 0.8313
# Epoch 3/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3611 - Accuracy: 0.8344
# Epoch 4/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3669 - Accuracy: 0.8219
# Epoch 5/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3620 - Accuracy: 0.8250
# Epoch 6/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3697 - Accuracy: 0.8281
# Epoch 7/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3691 - Accuracy: 0.8313
# Epoch 8/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3690 - Accuracy: 0.8313
# Epoch 9/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3618 - Accuracy: 0.8469
# Epoch 10/10
# 320/320 [==============================] - 1s 3ms/step - loss: 0.3612 - Accuracy: 0.8313
# 10.302316188812256

# %%
# But convergence of SGD is faster than GD
