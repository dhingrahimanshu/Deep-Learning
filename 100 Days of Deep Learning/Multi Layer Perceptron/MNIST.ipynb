# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense ,Flatten

# %%
(x_train , y_train) ,(x_test , y_test) = keras.datasets.mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train = x_train/255
x_test = x_test/255

# %%
import matplotlib.pyplot as plt

plt.imshow(x_train[0])

# %%
model = Sequential()

model.add(Flatten(input_shape = (28 , 28)))
model.add(Dense(128 , activation = 'relu'))
model.add(Dense(32 , activation = 'relu'))
model.add(Dense(10 , activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_6 (Flatten)         (None, 784)               0
#
#  dense_10 (Dense)            (None, 128)               100480
#
#  dense_11 (Dense)            (None, 32)                4128
#
#  dense_12 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 104938 (409.91 KB)
# Trainable params: 104938 (409.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss = 'sparse_categorical_crossentropy' , optimizer = 'Adam' , metrics = ['accuracy'])

# %%
history = model.fit(x_train , y_train , epochs = 20  , validation_split = 0.2)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.2829 - accuracy: 0.9161 - val_loss: 0.1396 - val_accuracy: 0.9596
# Epoch 2/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.1197 - accuracy: 0.9649 - val_loss: 0.1272 - val_accuracy: 0.9617
# Epoch 3/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0829 - accuracy: 0.9749 - val_loss: 0.0966 - val_accuracy: 0.9712
# Epoch 4/20
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0610 - accuracy: 0.9815 - val_loss: 0.0927 - val_accuracy: 0.9722
# Epoch 5/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0481 - accuracy: 0.9850 - val_loss: 0.1028 - val_accuracy: 0.9715
# Epoch 6/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0387 - accuracy: 0.9877 - val_loss: 0.1021 - val_accuracy: 0.9725
# Epoch 7/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0295 - accuracy: 0.9905 - val_loss: 0.1023 - val_accuracy: 0.9736
# Epoch 8/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0286 - accuracy: 0.9905 - val_loss: 0.1091 - val_accuracy: 0.9732
# Epoch 9/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0239 - accuracy: 0.9922 - val_loss: 0.1110 - val_accuracy: 0.9740
# Epoch 10/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0181 - accuracy: 0.9937 - val_loss: 0.1172 - val_accuracy: 0.9730
# Epoch 11/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.1242 - val_accuracy: 0.9740
# Epoch 12/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0151 - accuracy: 0.9948 - val_loss: 0.1160 - val_accuracy: 0.9757
# Epoch 13/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0153 - accuracy: 0.9949 - val_loss: 0.1194 - val_accuracy: 0.9754
# Epoch 14/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.1223 - val_accuracy: 0.9752
# Epoch 15/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0119 - accuracy: 0.9959 - val_loss: 0.1527 - val_accuracy: 0.9699
# Epoch 16/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0141 - accuracy: 0.9953 - val_loss: 0.1166 - val_accuracy: 0.9779
# Epoch 17/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0103 - accuracy: 0.9962 - val_loss: 0.1357 - val_accuracy: 0.9743
# Epoch 18/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0105 - accuracy: 0.9964 - val_loss: 0.1277 - val_accuracy: 0.9765
# Epoch 19/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.1431 - val_accuracy: 0.9762
# Epoch 20/20
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.1482 - val_accuracy: 0.9773

# %%
y_prob = model.predict(x_test)

y_pred = y_prob.argmax(axis = 1)
# Out:
# 313/313 [==============================] - 0s 867us/step

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test , y_pred)
# Out:
# 0.9744

# %%
plt.plot(history.history['loss'] , label = 'Loss')
plt.plot(history.history['val_loss'] , label = 'Validation_loss')
plt.legend()

# %%
plt.plot(history.history['accuracy'] , label = 'Accuracy')
plt.plot(history.history['val_accuracy'] , label = 'Val_Accuracy')

plt.legend()

# %%
import numpy as np

# %%
plt.imshow(x_test[0])

y_prob = model.predict(np.array([x_test[0]]))
print("This is",y_prob.argmax(axis =1)[0])
# Out:
# 1/1 [==============================] - 0s 16ms/step
# This is 7

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
np.array([x_test[0]]).shape
# Out:
# (1, 28, 28)
